# %%
import pandas as pd
import json
import requests
from pprint import pprint
import alpaca_trade_api as tradeapi
from time import sleep
base_url = 'https://paper-api.alpaca.markets'
api_key = 'PK31BC6XPUTS7CVHNJQ3'
secret_key = 'reFlvUBcJJ0U9i6iVJJDLtI3P55YGavixpjGvPny'
api = tradeapi.REST(api_key, secret_key,base_url)
df = pd.read_csv('./sp500list1.csv')
tckr = df['Symbol'].tolist()

# %%
tckr
# Out:
# ['MMM',
#  'ABT',
#  'ABBV',
#  'ABMD',
#  'ACN',
#  'ATVI',
#  'ADBE',
#  'AMD',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALXN',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'AOS',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ADM',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BKR',
#  'BLL',
#  'BAC',
#  'BK',
#  'BAX',
#  'BDX',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'BIIB',
#  'BLK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BF.B',
#  'CHRW',
#  'COG',
#  'CDNS',
#  'CZR',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'CNC',
#  'CNP',
# ...

# %%
price_info= []
count = 0
for i in tckr:
#     try:
    barset = api.get_barset(i, 'day', limit=500)
    tckr_infoopening1 = barset[i][0].o
    tckr_infoClosing1 = barset[i][0].c
    tckr_infoHigh1 = barset[i][0].h
    tckr_infoLow1 = barset[i][0].l
    tckr_infoHigh = barset[i][1].h

    info = {'Ticker':f'{i}',
            'openingY':tckr_infoopening1,
            'closingY':tckr_infoClosing1,
            'highY':tckr_infoHigh1,
            'lowY':tckr_infoLow1,
            'high':tckr_infoHigh
}
    pprint(i)
    
    count+=1
    price_info.append(info)
#         pprint(price_info)

        

#     except:
#         count+=1
        
#         print(f'result error{i}')
#         pass
# Out:
# 'MMM'
# 'ABT'
# 'ABBV'
# 'ABMD'
# 'ACN'
# 'ATVI'
# 'ADBE'
# 'AMD'
# 'AAP'
# 'AES'
# 'AFL'
# 'A'
# 'APD'
# 'AKAM'
# 'ALK'
# 'ALB'
# 'ARE'
# 'ALXN'
# 'ALGN'
# 'ALLE'
# 'LNT'
# 'ALL'
# 'GOOGL'
# 'GOOG'
# 'MO'
# 'AMZN'
# 'AMCR'
# 'AEE'
# 'AAL'
# 'AEP'
# 'AXP'
# 'AIG'
# 'AMT'
# 'AWK'
# 'AMP'
# 'ABC'
# 'AME'
# 'AMGN'
# 'APH'
# 'ADI'
# 'ANSS'
# 'ANTM'
# 'AON'
# 'AOS'
# 'APA'
# 'AAPL'
# 'AMAT'
# 'APTV'
# 'ADM'
# 'ANET'
# 'AJG'
# 'AIZ'
# 'T'
# 'ATO'
# 'ADSK'
# 'ADP'
# 'AZO'
# 'AVB'
# 'AVY'
# 'BKR'
# 'BLL'
# 'BAC'
# 'BK'
# 'BAX'
# 'BDX'
# 'BRK.B'
# 'BBY'
# 'BIO'
# 'BIIB'
# 'BLK'
# 'BA'
# 'BKNG'
# 'BWA'
# 'BXP'
# 'BSX'
# 'BMY'
# 'AVGO'
# 'BR'
# 'BF.B'
# 'CHRW'
# 'COG'
# 'CDNS'
# 'CZR'
# 'CPB'
# 'COF'
# 'CAH'
# 'KMX'
# 'CCL'
# 'CARR'
# 'CTLT'
# 'CAT'
# 'CBOE'
# 'CBRE'
# 'CDW'
# 'CE'
# 'CNC'
# 'CNP'
# 'CERN'
# 'CF'
# 'CRL'
# 'SCHW'
# 'CHTR'
# 'CVX'
# 'CMG'
# 'CB'
# 'CHD'
# 'CI'
# 'CINF'
# 'CTAS'
# 'CSCO'
# 'C'
# 'CFG'
# 'CTXS'
# 'CLX'
# 'CME'
# 'CMS'
# 'KO'
# 'CTSH'
# 'CL'
# 'CMCSA'
# 'CMA'
# ...

# %%
        pprint(price_info[0])
# Out:
# {'Ticker': 'SRCE',
#  'closingY': 48.72,
#  'high': 49.12,
#  'highY': 48.82,
#  'lowY': 47.96,
#  'openingY': 48.35}

# %%
df = pd.DataFrame(price_info)
df
# Out:
#     Ticker  openingY  closingY    highY    lowY     high
# 0      MMM    162.51    166.06  167.630  162.13  169.710
# 1      ABT     81.45     81.64   81.965   81.08   82.885
# 2     ABBV     76.39     76.53   76.790   76.22   78.380
# 3     ABMD    180.48    182.38  183.700  179.46  186.260
# 4      ACN    184.67    183.02  184.830  183.02  185.930
# ..     ...       ...       ...      ...     ...      ...
# 500    YUM    108.83    109.10  109.700  108.60  110.710
# 501   ZBRA    211.76    219.26  219.400  211.08  224.900
# 502    ZBH    134.96    134.07  135.120  133.94  137.000
# 503   ZION     47.46     47.94   48.370   47.43   48.980
# 504    ZTS    122.55    121.83  123.004  121.04  124.020
#
# [505 rows x 6 columns]

# %%
d = {'Ticker':[], 'date':[], 'sector':[],'opening':[],'closing':[], 'high':[], 'low':[]}
Odf = pd.DataFrame(d)
Odf

# %%
print(price_info[0]['high'])

# %%
for i in range(0,502):
    try:
        opening = price_info[i]['opening'] #pulls opening price list for the currently selected company
        close = price_info[i]['closing'] #pulls closing price list for the currently selected company
        high = price_info[i]['high'] #pulls high price list for the currently selected company
        low = price_info[i]['low'] #pulls low price list for the currently selected company
        ticker = price_info[i]['Ticker']
        name = price_info[i]['name']
        sector = price_info[i]['sector']
        Odf = Odf.append({'Ticker': ticker,
                        'date': today,
                        'sector': sector,
                        'high': high,
                        'low': low,
                        'sector': sector,
                        'opening': opening,
                        'closing': close,}, ignore_index=True)
    except:
        pass

# %%
Odf

# %%
df.to_csv(r'../Machine_learning/500Modeled.csv', index = False)

# %%
import os
from twilio.rest import Client


# Find your Account SID and Auth Token at twilio.com/console
# and set the environment variables. See http://twil.io/secure
account_sid = 'AC4ab3ece33d5bb0b0a6d617086b40ae98'
auth_token = '285a6c2756f288274702c9e3de20003c'
client = Client(account_sid, auth_token)

message = client.messages \
                .create(
                     body="Kyley has learned how to send text messages from python script. :)",
                     from_='++19703153376',
                     to='+13033044215'
                 )

print(message.sid)
